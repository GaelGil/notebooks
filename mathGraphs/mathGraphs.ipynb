# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
a = 1.5
b = -2.4
t = np.linspace(start=0, stop=5*math.pi, num=500)
x = (a + b*t) * (np.cos(t))
y = (a + b*t) * np.sin(t)
plt.plot(x,y)
plt.grid()
plt.show()
